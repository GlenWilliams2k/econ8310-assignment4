# %%
#import statements
import pandas as pd
import numpy as np
import pymc as pm
import arviz as az
from dataclasses import dataclass
from typing import List

#dataclasses
@dataclass
class BetaPrior:
    alpha: float
    beta: float

@dataclass
class BinomialData:
    trials: int #total number of players in a variant
    successes: int #number of players who converted

#get data
df = pd.read_csv("https://github.com/dustywhite7/Econ8310/raw/master/AssignmentData/cookie_cats.csv")

#boolin
df["retention_1"] = df["retention_1"].astype(int)
df["retention_7"] = df["retention_7"].astype(int)

agg1 = df.groupby("version")["retention_1"].agg(successes = "sum", trials = "count")
agg1 = agg1.loc[["gate_30", "gate_40"]]
agg1

binom_data_1day = [
    BinomialData(trials=int(row.trials), successes=int(row.successes)) for _, row in agg1.iterrows()]

binom_data_1day

agg7 = df.groupby("version")["retention_7"].agg(successes = "sum", trials = "count")
agg7 = agg7.loc[["gate_30", "gate_40"]]

binom_data_7day = [BinomialData(trials = int(row.trials), successes=int(row.successes)) for _, row in agg7.iterrows()]

#classy
class ConversionModelTwoVariant:
    def __init__(self, priors: BetaPrior):
        self.priors = priors

    def create_model(self, data: List[BinomialData]) -> pm.Model:
        trials = np.array([d.trials for d in data])
        successes = np.array([d.successes for d in data])
        with pm.Model() as model:
            p = pm.Beta("p", alpha = self.priors.alpha, beta = self.priors.beta, shape = len(data))
            obs = pm.Binomial("y", n = trials, p = p, observed = successes)
            reluplift = pm.Deterministic("reuplift_b", p[1] / p[0] - 1)
        return model

#binom_data_1day
#binom_data_7day

# %%
#its modelin time
priors = BetaPrior(alpha = 2.0, beta = 2.0)
conv_model = ConversionModelTwoVariant(priors = priors)

model_1day = conv_model.create_model(binom_data_1day)

with model_1day:
    trace_1day = pm.sample(draws = 2000, tune = 2000, chains = 2, random_seed = np.random.default_rng(42), progressbar= "combined+stats", target_accept = 0.9)

az.summary(trace_1day, var_names=["p", "reuplift_b"]) #summarize posterior
# Out:
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   0       0             0.000       0            0.00 draws/s     0:00:00   -:--:--
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   32      0             0.006       3            276.87 draws/s   0:00:00   0:00:28
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   76      0             0.007       3            336.16 draws/s   0:00:00   0:00:23
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    ---------------------------------------   143     0             0.004       7            422.05 draws/s   0:00:00   0:00:19
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    ---------------------------------------   182     0             0.007       7            409.40 draws/s   0:00:00   0:00:19
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   207     0             0.008       7            393.18 draws/s   0:00:00   0:00:20
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   208     0             0.015       127          355.12 draws/s   0:00:00   0:00:22
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   211     0             0.018       223          294.12 draws/s   0:00:00   0:00:27
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   215     0             0.032       43           246.73 draws/s   0:00:00   0:00:32
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   220     0             0.069       63           222.70 draws/s   0:00:00   0:00:35
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   228     0             0.201       9            207.96 draws/s   0:00:01   0:00:38
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   262     0             1.211       3            216.83 draws/s   0:00:01   0:00:36
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   301     0             0.834       3            228.26 draws/s   0:00:01   0:00:34
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   343     0             0.283       15           240.03 draws/s   0:00:01   0:00:32
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -- -------------------------------------   409     0             0.936       3            265.81 draws/s   0:00:01   0:00:29
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -- -------------------------------------   488     0             0.886       7            296.17 draws/s   0:00:01   0:00:26
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -- -------------------------------------   563     0             1.146       3            320.23 draws/s   0:00:01   0:00:24
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --- ------------------------------------   636     0             0.949       1            340.30 draws/s   0:00:01   0:00:22
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --- ------------------------------------   714     0             0.910       7            360.87 draws/s   0:00:01   0:00:21
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --- ------------------------------------   782     0             0.844       3            374.21 draws/s   0:00:02   0:00:20
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---- -----------------------------------   863     0             0.780       3            392.66 draws/s   0:00:02   0:00:19
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---- -----------------------------------   944     0             0.926       7            409.23 draws/s   0:00:02   0:00:18
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----- ----------------------------------   1024    0             0.903       7            424.20 draws/s   0:00:02   0:00:17
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----- ----------------------------------   1106    0             0.681       1            437.91 draws/s   0:00:02   0:00:16
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----- ----------------------------------   1181    0             0.913       3            448.52 draws/s   0:00:02   0:00:15
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------ ---------------------------------   1260    0             0.942       3            459.70 draws/s   0:00:02   0:00:11
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------ ---------------------------------   1338    0             1.110       3            469.08 draws/s   0:00:02   0:00:10
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------- --------------------------------   1406    0             1.154       3            474.96 draws/s   0:00:02   0:00:10
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------- --------------------------------   1488    0             1.152       3            484.84 draws/s   0:00:03   0:00:10
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------- --------------------------------   1567    0             0.774       3            492.89 draws/s   0:00:03   0:00:10
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------- -------------------------------   1641    0             0.750       3            499.32 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------- -------------------------------   1714    0             0.800       3            504.68 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------- -------------------------------   1791    0             1.000       3            510.61 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------- ------------------------------   1866    0             0.857       7            516.17 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------- ------------------------------   1939    0             0.857       1            520.25 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------- -----------------------------   2014    0             0.972       7            525.34 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------- -----------------------------   2083    0             0.785       3            528.09 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------- -----------------------------   2146    0             1.102       3            529.20 draws/s   0:00:04   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------- ----------------------------   2225    0             0.890       7            533.94 draws/s   0:00:04   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------- ----------------------------   2300    0             0.989       3            537.89 draws/s   0:00:04   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------- ----------------------------   2371    0             0.935       3            540.88 draws/s   0:00:04   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------ ---------------------------   2443    0             0.951       3            543.67 draws/s   0:00:04   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------ ---------------------------   2512    0             1.100       3            546.25 draws/s   0:00:04   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------ ---------------------------   2589    0             0.929       3            549.74 draws/s   0:00:04   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------- --------------------------   2667    0             1.176       3            553.40 draws/s   0:00:04   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------- --------------------------   2754    0             0.931       3            558.62 draws/s   0:00:04   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------- -------------------------   2837    0             0.807       3            562.94 draws/s   0:00:05   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------- -------------------------   2910    0             0.911       3            565.18 draws/s   0:00:05   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------- -------------------------   2989    0             0.797       7            568.54 draws/s   0:00:05   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------- ------------------------   3062    0             0.937       3            570.64 draws/s   0:00:05   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------- ------------------------   3139    0             1.081       3            573.37 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------- -----------------------   3223    0             0.798       1            576.96 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------- -----------------------   3296    0             0.800       3            578.71 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------- -----------------------   3350    0             0.957       3            576.88 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------- ----------------------   3429    0             1.065       3            579.82 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------- ----------------------   3502    0             0.908       3            581.42 draws/s   0:00:06   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------- ----------------------   3577    0             0.862       3            583.40 draws/s   0:00:06   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------ ---------------------   3651    0             0.916       3            584.97 draws/s   0:00:06   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------ ---------------------   3724    0             0.918       1            586.26 draws/s   0:00:06   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------- --------------------   3807    0             1.063       3            589.22 draws/s   0:00:06   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------- --------------------   3889    0             0.943       3            591.87 draws/s   0:00:06   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------- --------------------   3970    0             0.943       1            594.41 draws/s   0:00:06   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------- -------------------   4044    0             0.801       1            595.63 draws/s   0:00:06   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------- -------------------   4125    0             0.944       3            597.92 draws/s   0:00:06   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------------- ------------------   4209    0             0.943       3            600.74 draws/s   0:00:07   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------------- ------------------   4288    0             0.943       7            602.52 draws/s   0:00:07   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------------- ------------------   4367    0             0.943       3            604.32 draws/s   0:00:07   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------- -----------------   4444    0             0.920       3            605.62 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------- -----------------   4521    0             0.920       3            607.25 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------- ----------------   4605    0             0.943       1            609.58 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------- ----------------   4684    0             0.920       7            611.06 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------- ----------------   4760    0             0.920       3            612.26 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------ ---------------   4836    0             0.920       3            613.50 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------ ---------------   4919    0             0.920       3            615.54 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------- --------------   5002    0             0.943       1            617.29 draws/s   0:00:08   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------- --------------   5079    0             0.920       3            618.59 draws/s   0:00:08   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------- --------------   5163    0             0.920       3            620.49 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------------- -------------   5243    0             0.920       3            622.08 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------------- -------------   5305    0             0.920       3            621.39 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------------- -------------   5387    0             0.943       3            622.92 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------------------- ------------   5467    0             0.943       3            624.20 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------------------- ------------   5550    0             0.920       7            625.78 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------- -----------   5632    0             0.943       3            627.50 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------- -----------   5711    0             0.943       7            628.38 draws/s   0:00:09   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------- -----------   5793    0             0.943       7            630.02 draws/s   0:00:09   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------- ----------   5872    0             0.920       3            631.10 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------- ----------   5960    0             0.920       3            633.21 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------ ---------   6045    0             0.920       3            634.83 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------ ---------   6125    0             0.943       7            635.90 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------- --------   6204    0             0.943       7            636.85 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------- --------   6282    0             0.943       3            637.75 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
# ...
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------------------------- ------   6684    0             0.943       3            642.84 draws/s   0:00:10   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------------------------- ------   6769    0             0.943       3            644.12 draws/s   0:00:10   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------- -----   6849    0             0.920       3            645.26 draws/s   0:00:10   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------- -----   6912    0             0.943       1            644.39 draws/s   0:00:10   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------- -----   6994    0             0.920       3            645.40 draws/s   0:00:10   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------- ----   7069    0             0.943       3            645.77 draws/s   0:00:10   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------- ----   7145    0             0.943       3            646.47 draws/s   0:00:11   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------------ ---   7227    0             0.943       3            647.48 draws/s   0:00:11   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------------ ---   7309    0             0.943       3            648.44 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------------ ---   7390    0             0.920       3            649.40 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------------- --   7477    0             0.943       7            650.74 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------------- --   7561    0             0.920       7            651.85 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------------------------- -   7645    0             0.943       3            652.81 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------------------------- -   7728    0             0.943       1            653.78 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7814    0             0.943       3            655.06 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7897    0             0.920       3            655.90 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7963    0             0.943       3            656.74 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7963    0             0.943       3            656.74 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7963    0             0.943       3            656.74 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7963    0             0.943       3            656.74 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7963    0             0.943       3            656.74 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7963    0             0.943       3            656.74 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7977    0             0.920       3            628.29 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.920       3            627.16 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.920       3            627.16 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.920       3            627.16 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.920       3            627.16 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.920       3            627.16 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.920       3            627.16 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.920       3            627.16 draws/s   0:00:12   0:00:00
#              mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  r_hat
# p[0]        0.448  0.002   0.444    0.453        0.0      0.0    3691.0    2909.0    1.0
# p[1]        0.442  0.002   0.438    0.447        0.0      0.0    3580.0    2857.0    1.0
# reuplift_b -0.013  0.008  -0.027    0.002        0.0      0.0    3788.0    2698.0    1.0

# %%
#7day
model_7day = conv_model.create_model(binom_data_7day)

with model_7day:
    trace_7day = pm.sample(draws = 2000, tune = 2000, chains = 2, random_seed = np.random.default_rng(42), progressbar= "combined+stats", target_accept = 0.9)

az.summary(trace_7day, var_names=["p", "reuplift_b"]) #summarize posterior
# Out:
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   0       0             0.000       0            0.00 draws/s     0:00:00   -:--:--
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   32      0             0.003       1            296.32 draws/s   0:00:00   0:00:26
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   74      0             0.007       3            336.36 draws/s   0:00:00   0:00:23
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    ---------------------------------------   140     0             0.013       3            425.71 draws/s   0:00:00   0:00:19
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    ---------------------------------------   187     0             0.009       3            425.43 draws/s   0:00:00   0:00:19
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   209     0             0.012       63           396.90 draws/s   0:00:00   0:00:20
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   211     0             0.025       191          352.11 draws/s   0:00:00   0:00:22
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   214     0             0.037       127          287.69 draws/s   0:00:00   0:00:27
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   222     0             0.115       31           252.15 draws/s   0:00:00   0:00:31
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   232     0             0.431       7            233.76 draws/s   0:00:00   0:00:34
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   267     0             0.968       1            242.92 draws/s   0:00:01   0:00:32
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   308     0             0.762       7            255.70 draws/s   0:00:01   0:00:30
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   - --------------------------------------   363     0             0.907       3            275.74 draws/s   0:00:01   0:00:28
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -- -------------------------------------   438     0             0.896       3            307.28 draws/s   0:00:01   0:00:25
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -- -------------------------------------   510     0             0.811       3            332.02 draws/s   0:00:01   0:00:23
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -- -------------------------------------   574     0             0.939       3            348.78 draws/s   0:00:01   0:00:22
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --- ------------------------------------   642     0             0.956       7            365.66 draws/s   0:00:01   0:00:21
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --- ------------------------------------   713     0             1.161       3            383.22 draws/s   0:00:01   0:00:19
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --- ------------------------------------   793     0             0.841       3            402.37 draws/s   0:00:01   0:00:18
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---- -----------------------------------   871     0             1.190       1            418.71 draws/s   0:00:02   0:00:17
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---- -----------------------------------   952     0             0.988       1            434.74 draws/s   0:00:02   0:00:17
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----- ----------------------------------   1035    0             0.773       3            450.31 draws/s   0:00:02   0:00:16
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----- ----------------------------------   1112    0             1.053       3            461.75 draws/s   0:00:02   0:00:15
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----- ----------------------------------   1188    0             0.968       3            471.65 draws/s   0:00:02   0:00:15
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------ ---------------------------------   1274    0             0.831       7            484.62 draws/s   0:00:02   0:00:11
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------ ---------------------------------   1344    0             0.761       3            491.15 draws/s   0:00:02   0:00:10
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------- --------------------------------   1422    0             0.905       3            499.99 draws/s   0:00:02   0:00:10
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------- --------------------------------   1501    0             0.946       7            508.11 draws/s   0:00:02   0:00:10
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------- --------------------------------   1581    0             0.734       3            515.91 draws/s   0:00:03   0:00:10
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------- -------------------------------   1655    0             1.062       3            521.41 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------- -------------------------------   1731    0             0.774       3            527.63 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------- ------------------------------   1809    0             1.016       7            533.64 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------- ------------------------------   1887    0             1.283       1            538.81 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------- ------------------------------   1969    0             1.171       1            545.04 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------- -----------------------------   2047    0             1.051       3            549.93 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------- -----------------------------   2120    0             0.798       7            553.17 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------- -----------------------------   2190    0             0.620       7            555.76 draws/s   0:00:03   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------- ----------------------------   2266    0             0.770       3            559.61 draws/s   0:00:04   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------- ----------------------------   2339    0             0.872       7            562.30 draws/s   0:00:04   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------ ---------------------------   2411    0             0.980       3            565.20 draws/s   0:00:04   0:00:09
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------ ---------------------------   2490    0             0.984       3            569.30 draws/s   0:00:04   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------ ---------------------------   2574    0             0.786       3            573.88 draws/s   0:00:04   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------- --------------------------   2659    0             0.924       3            578.38 draws/s   0:00:04   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------- --------------------------   2742    0             0.947       3            582.74 draws/s   0:00:04   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------- -------------------------   2822    0             1.075       1            585.88 draws/s   0:00:04   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------- -------------------------   2908    0             0.794       3            590.27 draws/s   0:00:04   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------- -------------------------   2988    0             0.738       3            593.45 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------- ------------------------   3040    0             0.818       7            591.30 draws/s   0:00:05   0:00:08
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------- ------------------------   3127    0             0.760       3            595.24 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------- -----------------------   3203    0             0.987       3            597.09 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------- -----------------------   3278    0             0.683       3            599.09 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------- -----------------------   3351    0             1.040       3            600.58 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------- ----------------------   3424    0             0.950       7            601.61 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------- ----------------------   3503    0             1.078       3            603.81 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------- ----------------------   3583    0             0.969       3            606.36 draws/s   0:00:05   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------ ---------------------   3665    0             1.015       3            609.14 draws/s   0:00:06   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------ ---------------------   3742    0             1.040       3            610.61 draws/s   0:00:06   0:00:07
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------- --------------------   3822    0             0.963       7            613.11 draws/s   0:00:06   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------- --------------------   3911    0             0.945       3            616.52 draws/s   0:00:06   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------- --------------------   3984    0             1.038       3            617.58 draws/s   0:00:06   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------- -------------------   4062    0             0.964       3            618.91 draws/s   0:00:06   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------- -------------------   4146    0             0.864       3            621.23 draws/s   0:00:06   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------------- ------------------   4230    0             0.864       3            623.58 draws/s   0:00:06   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------------- ------------------   4304    0             1.038       3            624.59 draws/s   0:00:06   0:00:06
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------------- ------------------   4384    0             0.864       3            626.60 draws/s   0:00:06   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------- -----------------   4463    0             1.038       3            628.03 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------- -----------------   4540    0             0.864       3            628.98 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------- ----------------   4617    0             0.864       3            630.01 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------- ----------------   4691    0             1.038       3            630.79 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------- ----------------   4775    0             0.864       1            632.66 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------ ---------------   4852    0             1.038       7            633.83 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------ ---------------   4923    0             0.864       7            633.85 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------- --------------   5007    0             1.038       3            635.83 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------- --------------   5090    0             1.038       3            637.58 draws/s   0:00:07   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------- --------------   5160    0             0.864       3            636.61 draws/s   0:00:08   0:00:05
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------------- -------------   5239    0             0.864       3            637.65 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------------- -------------   5316    0             0.864       3            638.35 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------------- -------------   5389    0             1.038       3            638.95 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------------------- ------------   5472    0             1.038       3            640.32 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   --------------------------- ------------   5551    0             1.038       3            641.36 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------- -----------   5624    0             1.038       3            641.61 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------- -----------   5703    0             0.864       7            642.43 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------- -----------   5793    0             0.864       7            644.49 draws/s   0:00:08   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------- ----------   5867    0             1.038       7            644.94 draws/s   0:00:09   0:00:04
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------- ----------   5934    0             0.864       7            644.59 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------ ---------   6012    0             0.864       3            645.54 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------ ---------   6095    0             0.864       3            646.70 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------ ---------   6168    0             1.038       3            646.98 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------- --------   6235    0             1.038       3            646.84 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------- --------   6308    0             0.864       7            646.98 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------- --------   6389    0             0.864       1            648.00 draws/s   0:00:09   0:00:03
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
# ...
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------- -----   6952    0             0.864       3            654.59 draws/s   0:00:10   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------- ----   7032    0             0.864       3            655.35 draws/s   0:00:10   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------- ----   7091    0             0.864       3            654.28 draws/s   0:00:10   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------- ----   7165    0             0.864       1            654.67 draws/s   0:00:10   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------------ ---   7245    0             1.038       3            655.58 draws/s   0:00:11   0:00:02
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------------ ---   7306    0             0.864       3            654.73 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------------ ---   7390    0             1.038       3            655.89 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------------- --   7471    0             0.864       3            656.58 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ------------------------------------- --   7552    0             1.038       7            657.43 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------------------------- -   7631    0             1.038       3            658.26 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------------------------- -   7714    0             0.864       7            659.05 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   -------------------------------------- -   7796    0             0.864       3            659.78 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7874    0             1.038       3            660.24 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7880    0             1.038       3            660.34 draws/s   0:00:11   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7880    0             1.038       3            660.34 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7880    0             1.038       3            660.34 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7880    0             1.038       3            660.34 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7880    0             1.038       3            660.34 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7880    0             1.038       3            660.34 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7904    0             0.864       7            628.39 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7943    0             0.864       3            626.06 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ---------------------------------------    7983    0             0.864       3            623.80 draws/s   0:00:12   0:00:01
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.864       3            622.92 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.864       3            622.92 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.864       3            622.92 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.864       3            622.92 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.864       3            622.92 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.864       3            622.92 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.864       3            622.92 draws/s   0:00:12   0:00:00
#
#   Progress                                   Draws   Divergences   Step size   Grad evals   Sampling Speed   Elapsed   Remaining
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ----------------------------------------   8000    0             0.864       3            622.92 draws/s   0:00:12   0:00:00
#              mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  r_hat
# p[0]        0.190  0.002   0.187    0.194        0.0      0.0    3511.0    2674.0    1.0
# p[1]        0.182  0.002   0.179    0.185        0.0      0.0    4494.0    2991.0    1.0
# reuplift_b -0.043  0.013  -0.067   -0.018        0.0      0.0    3673.0    2784.0    1.0
